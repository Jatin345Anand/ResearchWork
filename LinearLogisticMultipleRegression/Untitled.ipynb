# %%
import csv
import math
import random

# %%
# cv.read('http://localhost:8888/edit/ClusterClassificationResearchWork/LinearLogisticMultipleRegression/')
path = 'pima-indians-diabetes.datalogistic.csv'
def LoadDataset(path):
    fields =[]
    rows =[]
    with open(path,'r') as csvfile:
        csvreader = csv.reader(csvfile)
#         fields = csvreader.next()
        for row in csvreader:
            rows.append(row)
    return rows

# %%
# print(LoadDataset(path))
ROWS = LoadDataset(path)
print(len(ROWS))
def Str_To_Float(rows):
    for row in range(len(rows)):
        for s in range(len(rows[row])):
            print(float(rows[row][s]))
#         print(float(rows[row]))
#         print(rows[row])

Str_To_Float(ROWS)
# Out:
# 768
# 6.0
# 148.0
# 72.0
# 35.0
# 0.0
# 33.6
# 0.627
# 50.0
# 1.0
# 1.0
# 85.0
# 66.0
# 29.0
# 0.0
# 26.6
# 0.351
# 31.0
# 0.0
# 8.0
# 183.0
# 64.0
# 0.0
# 0.0
# 23.3
# 0.672
# 32.0
# 1.0
# 1.0
# 89.0
# 66.0
# 23.0
# 94.0
# 28.1
# 0.167
# 21.0
# 0.0
# 0.0
# 137.0
# 40.0
# 35.0
# 168.0
# 43.1
# 2.288
# 33.0
# 1.0
# 5.0
# 116.0
# 74.0
# 0.0
# 0.0
# 25.6
# 0.201
# 30.0
# 0.0
# 3.0
# 78.0
# 50.0
# 32.0
# 88.0
# 31.0
# 0.248
# 26.0
# 1.0
# 10.0
# 115.0
# 0.0
# 0.0
# 0.0
# 35.3
# 0.134
# 29.0
# 0.0
# 2.0
# 197.0
# 70.0
# 45.0
# 543.0
# 30.5
# 0.158
# 53.0
# 1.0
# 8.0
# 125.0
# 96.0
# 0.0
# 0.0
# 0.0
# 0.232
# 54.0
# 1.0
# 4.0
# 110.0
# 92.0
# 0.0
# 0.0
# 37.6
# 0.191
# 30.0
# 0.0
# 10.0
# 168.0
# 74.0
# 0.0
# 0.0
# 38.0
# 0.537
# 34.0
# 1.0
# 10.0
# 139.0
# 80.0
# 0.0
# 0.0
# 27.1
# 1.441
# 57.0
# 0.0
# 1.0
# 189.0
# 60.0
# 23.0
# 846.0
# 30.1
# 0.398
# 59.0
# 1.0
# 5.0
# 166.0
# 72.0
# 19.0
# 175.0
# 25.8
# 0.587
# 51.0
# 1.0
# 7.0
# 100.0
# 0.0
# 0.0
# 0.0
# 30.0
# 0.484
# 32.0
# 1.0
# ...
